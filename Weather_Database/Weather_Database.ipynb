# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Get the nearest city using citipy module
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Perfom API call using OpenWeatherMap

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If error, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | coetupo
# City not found. Skipping...
# Processing Record 3 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | mehamn
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | kalat
# Processing Record 12 of Set 1 | flinders
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | yuncheng
# Processing Record 18 of Set 1 | virginia beach
# Processing Record 19 of Set 1 | kiunga
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | tutoia
# Processing Record 24 of Set 1 | north bend
# Processing Record 25 of Set 1 | muisne
# Processing Record 26 of Set 1 | rawson
# Processing Record 27 of Set 1 | mizdah
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | anaconda
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | wembley
# Processing Record 33 of Set 1 | cabo san lucas
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | uniao da victoria
# City not found. Skipping...
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 1 | pinas
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | marsaxlokk
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | banamba
# Processing Record 47 of Set 1 | lavrentiya
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | strezhevoy
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | berlevag
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | tiznit
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | yakeshi
# Processing Record 10 of Set 2 | benjamin constant
# Processing Record 11 of Set 2 | ouadda
# Processing Record 12 of Set 2 | wagar
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 2 | aljezur
# Processing Record 20 of Set 2 | cap-aux-meules
# Processing Record 21 of Set 2 | agucadoura
# Processing Record 22 of Set 2 | shirgaon
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | labuhan
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 2 | namatanai
# Processing Record 31 of Set 2 | riyadh
# Processing Record 32 of Set 2 | mehriz
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | soe
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | lengshuitan
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | viransehir
# Processing Record 41 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 2 | tessalit
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 | broome
# Processing Record 45 of Set 2 | khuzhir
# Processing Record 46 of Set 2 | srandakan
# Processing Record 47 of Set 2 | marzuq
# Processing Record 48 of Set 2 | pak phanang
# Processing Record 49 of Set 2 | goiatuba
# Processing Record 50 of Set 2 | moose factory
# Processing Record 1 of Set 3 | portel
# Processing Record 2 of Set 3 | wewak
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | cootamundra
# Processing Record 5 of Set 3 | aksu
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 3 | erzin
# Processing Record 9 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 3 | fort nelson
# Processing Record 11 of Set 3 | coahuayana
# Processing Record 12 of Set 3 | zambezi
# Processing Record 13 of Set 3 | along
# Processing Record 14 of Set 3 | seaforth
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | spas-demensk
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | santona
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | port-gentil
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | qaqortoq
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 3 | nuuk
# Processing Record 28 of Set 3 | ewa beach
# Processing Record 29 of Set 3 | visnes
# Processing Record 30 of Set 3 | mill valley
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | chore
# City not found. Skipping...
# Processing Record 35 of Set 3 | hobyo
# Processing Record 36 of Set 3 | seoul
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | thompson
# Processing Record 39 of Set 3 | sarishabari
# Processing Record 40 of Set 3 | high level
# Processing Record 41 of Set 3 | martapura
# Processing Record 42 of Set 3 | nome
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | poya
# Processing Record 47 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | chom bung
# City not found. Skipping...
# Processing Record 50 of Set 3 | marrakesh
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | calvinia
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | ranong
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | waingapu
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | kars
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | llanes
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | hualmay
# Processing Record 19 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 4 | mashhad
# Processing Record 21 of Set 4 | mount isa
# Processing Record 22 of Set 4 | djambala
# Processing Record 23 of Set 4 | porbandar
# Processing Record 24 of Set 4 | cayenne
# Processing Record 25 of Set 4 | mecca
# Processing Record 26 of Set 4 | barra de sao francisco
# Processing Record 27 of Set 4 | the valley
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | chipinge
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | katsuura
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | cidreira
# Processing Record 34 of Set 4 | samdari
# Processing Record 35 of Set 4 | banda aceh
# Processing Record 36 of Set 4 | kandrian
# Processing Record 37 of Set 4 | acari
# Processing Record 38 of Set 4 | nushki
# Processing Record 39 of Set 4 | romny
# Processing Record 40 of Set 4 | half moon bay
# Processing Record 41 of Set 4 | jalu
# Processing Record 42 of Set 4 | meadow lake
# Processing Record 43 of Set 4 | sherbakul
# Processing Record 44 of Set 4 | farias brito
# Processing Record 45 of Set 4 | mandalgovi
# Processing Record 46 of Set 4 | shingu
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | wittmund
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | pithoro
# Processing Record 1 of Set 5 | nevyansk
# Processing Record 2 of Set 5 | floro
# Processing Record 3 of Set 5 | kintampo
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | sandwick
# Processing Record 6 of Set 5 | cachoeirinha
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | ajaccio
# Processing Record 9 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 5 | bluff
# Processing Record 11 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 5 | alyangula
# Processing Record 13 of Set 5 | nhulunbuy
# Processing Record 14 of Set 5 | akyab
# Processing Record 15 of Set 5 | tulum
# Processing Record 16 of Set 5 | fairbanks
# Processing Record 17 of Set 5 | padalarang
# Processing Record 18 of Set 5 | qom
# Processing Record 19 of Set 5 | sambava
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | xiongzhou
# Processing Record 22 of Set 5 | pemangkat
# Processing Record 23 of Set 5 | cochabamba
# Processing Record 24 of Set 5 | mirnyy
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | igrim
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | goderich
# Processing Record 30 of Set 5 | aitape
# Processing Record 31 of Set 5 | saint-louis
# Processing Record 32 of Set 5 | lasa
# Processing Record 33 of Set 5 | new glasgow
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | koslan
# Processing Record 36 of Set 5 | anadyr
# Processing Record 37 of Set 5 | oranjemund
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | sakakah
# Processing Record 40 of Set 5 | khandyga
# Processing Record 41 of Set 5 | sussex
# Processing Record 42 of Set 5 | beni suef
# Processing Record 43 of Set 5 | atar
# Processing Record 44 of Set 5 | hatillo
# Processing Record 45 of Set 5 | nipawin
# Processing Record 46 of Set 5 | njombe
# Processing Record 47 of Set 5 | taoudenni
# Processing Record 48 of Set 5 | manado
# Processing Record 49 of Set 5 | buluang
# Processing Record 50 of Set 5 | san cristobal
# Processing Record 1 of Set 6 | lyuban
# Processing Record 2 of Set 6 | polunochnoye
# Processing Record 3 of Set 6 | nanakuli
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | zacualpan
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | waipawa
# Processing Record 11 of Set 6 | kavaratti
# Processing Record 12 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 6 | bima
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | camana
# Processing Record 16 of Set 6 | semirom
# Processing Record 17 of Set 6 | nizwa
# Processing Record 18 of Set 6 | ust-tsilma
# Processing Record 19 of Set 6 | xingyi
# Processing Record 20 of Set 6 | chatakonda
# Processing Record 21 of Set 6 | ilulissat
# Processing Record 22 of Set 6 | zaysan
# Processing Record 23 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | chiang mai
# Processing Record 26 of Set 6 | siilinjarvi
# Processing Record 27 of Set 6 | pisco
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | kahului
# Processing Record 30 of Set 6 | torbay
# Processing Record 31 of Set 6 | dhidhdhoo
# Processing Record 32 of Set 6 | nishihara
# Processing Record 33 of Set 6 | boulder
# Processing Record 34 of Set 6 | caranan
# Processing Record 35 of Set 6 | kant
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 6 | maxixe
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | cairns
# Processing Record 41 of Set 6 | luanda
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | aswan
# Processing Record 44 of Set 6 | marysville
# Processing Record 45 of Set 6 | lahat
# Processing Record 46 of Set 6 | lahij
# Processing Record 47 of Set 6 | xichang
# Processing Record 48 of Set 6 | badarganj
# Processing Record 49 of Set 6 | mamakan
# Processing Record 50 of Set 6 | adrar
# Processing Record 1 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | oistins
# Processing Record 4 of Set 7 | piacabucu
# Processing Record 5 of Set 7 | agadir
# Processing Record 6 of Set 7 | kenai
# Processing Record 7 of Set 7 | burica
# City not found. Skipping...
# Processing Record 8 of Set 7 | devils lake
# Processing Record 9 of Set 7 | castro
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | pirenopolis
# Processing Record 12 of Set 7 | villanueva
# Processing Record 13 of Set 7 | ozernovskiy
# Processing Record 14 of Set 7 | severnyy
# Processing Record 15 of Set 7 | rengo
# Processing Record 16 of Set 7 | bulgan
# Processing Record 17 of Set 7 | camacha
# Processing Record 18 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 7 | huarmey
# Processing Record 20 of Set 7 | ketchikan
# Processing Record 21 of Set 7 | boddam
# Processing Record 22 of Set 7 | lodja
# Processing Record 23 of Set 7 | ulaangom
# Processing Record 24 of Set 7 | susa
# Processing Record 25 of Set 7 | talakan
# Processing Record 26 of Set 7 | sumbe
# Processing Record 27 of Set 7 | nizhneangarsk
# Processing Record 28 of Set 7 | merauke
# Processing Record 29 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 7 | sabang
# Processing Record 31 of Set 7 | sokoni
# Processing Record 32 of Set 7 | pontian kecil
# Processing Record 33 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 7 | moerai
# Processing Record 35 of Set 7 | hofn
# Processing Record 36 of Set 7 | nago
# Processing Record 37 of Set 7 | ellisras
# Processing Record 38 of Set 7 | ust-ilimsk
# Processing Record 39 of Set 7 | manggar
# Processing Record 40 of Set 7 | tsiroanomandidy
# Processing Record 41 of Set 7 | guilin
# Processing Record 42 of Set 7 | mogadishu
# Processing Record 43 of Set 7 | iquique
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | batagay-alyta
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | marsh harbour
# Processing Record 49 of Set 7 | joshimath
# Processing Record 50 of Set 7 | chigorodo
# Processing Record 1 of Set 8 | odweyne
# Processing Record 2 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 3 of Set 8 | villamontes
# Processing Record 4 of Set 8 | ayan
# Processing Record 5 of Set 8 | caravelas
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | henties bay
# Processing Record 8 of Set 8 | bayugan
# Processing Record 9 of Set 8 | lufkin
# Processing Record 10 of Set 8 | la cruz
# Processing Record 11 of Set 8 | hami
# Processing Record 12 of Set 8 | quatre cocos
# Processing Record 13 of Set 8 | touros
# Processing Record 14 of Set 8 | chuy
# Processing Record 15 of Set 8 | xuddur
# Processing Record 16 of Set 8 | ocos
# Processing Record 17 of Set 8 | bongandanga
# Processing Record 18 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 8 | varna
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | salalah
# Processing Record 22 of Set 8 | qasigiannguit
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | guhagar
# Processing Record 25 of Set 8 | gombong
# Processing Record 26 of Set 8 | sevierville
# Processing Record 27 of Set 8 | cabra
# Processing Record 28 of Set 8 | port hueneme
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | avera
# Processing Record 31 of Set 8 | pafos
# Processing Record 32 of Set 8 | ribas do rio pardo
# Processing Record 33 of Set 8 | santa rosa
# Processing Record 34 of Set 8 | longyearbyen
# Processing Record 35 of Set 8 | tamworth
# Processing Record 36 of Set 8 | haputale
# Processing Record 37 of Set 8 | agnibilekrou
# Processing Record 38 of Set 8 | bridlington
# Processing Record 39 of Set 8 | yuanping
# Processing Record 40 of Set 8 | westport
# Processing Record 41 of Set 8 | poum
# Processing Record 42 of Set 8 | tromso
# Processing Record 43 of Set 8 | bunbury
# Processing Record 44 of Set 8 | sinnamary
# Processing Record 45 of Set 8 | koutiala
# Processing Record 46 of Set 8 | mata
# Processing Record 47 of Set 8 | yulara
# Processing Record 48 of Set 8 | vammala
# Processing Record 49 of Set 8 | siloam springs
# Processing Record 50 of Set 8 | makakilo city
# Processing Record 1 of Set 9 | general roca
# Processing Record 2 of Set 9 | roma
# Processing Record 3 of Set 9 | artur nogueira
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | casa nova
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | san antonio
# Processing Record 8 of Set 9 | shahrud
# Processing Record 9 of Set 9 | opuwo
# Processing Record 10 of Set 9 | san jose
# Processing Record 11 of Set 9 | shubarkuduk
# Processing Record 12 of Set 9 | verkhnevilyuysk
# Processing Record 13 of Set 9 | khandbari
# Processing Record 14 of Set 9 | naze
# Processing Record 15 of Set 9 | calubcub
# City not found. Skipping...
# Processing Record 16 of Set 9 | usinsk
# Processing Record 17 of Set 9 | ardon
# Processing Record 18 of Set 9 | udachnyy
# Processing Record 19 of Set 9 | sorokino
# Processing Record 20 of Set 9 | tigre
# Processing Record 21 of Set 9 | berbera
# Processing Record 22 of Set 9 | veraval
# Processing Record 23 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 9 | bogo
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | luleburgaz
# Processing Record 28 of Set 9 | qui nhon
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | kuusamo
# Processing Record 31 of Set 9 | san carlos de bariloche
# Processing Record 32 of Set 9 | san fernando
# Processing Record 33 of Set 9 | butterworth
# Processing Record 34 of Set 9 | houma
# Processing Record 35 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 9 | utiel
# Processing Record 37 of Set 9 | twistringen
# Processing Record 38 of Set 9 | brawley
# Processing Record 39 of Set 9 | vestmanna
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | rabo de peixe
# Processing Record 42 of Set 9 | nemuro
# Processing Record 43 of Set 9 | traiguen
# Processing Record 44 of Set 9 | broken hill
# Processing Record 45 of Set 9 | tazovskiy
# Processing Record 46 of Set 9 | teknaf
# Processing Record 47 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 48 of Set 9 | surt
# Processing Record 49 of Set 9 | surazh
# Processing Record 50 of Set 9 | port hedland
# Processing Record 1 of Set 10 | soroti
# Processing Record 2 of Set 10 | rumford
# Processing Record 3 of Set 10 | tombouctou
# Processing Record 4 of Set 10 | sola
# Processing Record 5 of Set 10 | santa cruz
# Processing Record 6 of Set 10 | kruisfontein
# Processing Record 7 of Set 10 | darovskoy
# Processing Record 8 of Set 10 | rognac
# Processing Record 9 of Set 10 | upernavik
# Processing Record 10 of Set 10 | pringsewu
# Processing Record 11 of Set 10 | kyrylivka
# Processing Record 12 of Set 10 | severo-kurilsk
# Processing Record 13 of Set 10 | amanpur
# Processing Record 14 of Set 10 | male
# Processing Record 15 of Set 10 | havoysund
# Processing Record 16 of Set 10 | kondinskoye
# Processing Record 17 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | kilindoni
# Processing Record 20 of Set 10 | kinablangan
# Processing Record 21 of Set 10 | netivot
# Processing Record 22 of Set 10 | rosetta
# Processing Record 23 of Set 10 | bastia
# Processing Record 24 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 10 | warrnambool
# Processing Record 26 of Set 10 | salinas
# Processing Record 27 of Set 10 | yining
# Processing Record 28 of Set 10 | haines junction
# Processing Record 29 of Set 10 | kutum
# Processing Record 30 of Set 10 | ahipara
# Processing Record 31 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 10 | tuatapere
# Processing Record 33 of Set 10 | ponta delgada
# Processing Record 34 of Set 10 | karratha
# Processing Record 35 of Set 10 | san policarpo
# Processing Record 36 of Set 10 | ippy
# Processing Record 37 of Set 10 | bukachacha
# Processing Record 38 of Set 10 | pangkalanbuun
# Processing Record 39 of Set 10 | paka
# Processing Record 40 of Set 10 | amarante do maranhao
# Processing Record 41 of Set 10 | zabaykalsk
# Processing Record 42 of Set 10 | port macquarie
# Processing Record 43 of Set 10 | sugal
# Processing Record 44 of Set 10 | sangar
# Processing Record 45 of Set 10 | faro
# Processing Record 46 of Set 10 | ossora
# Processing Record 47 of Set 10 | subate
# Processing Record 48 of Set 10 | nova olinda do norte
# Processing Record 49 of Set 10 | ganzhou
# Processing Record 50 of Set 10 | ghanzi
# Processing Record 1 of Set 11 | constitucion
# Processing Record 2 of Set 11 | labuan
# Processing Record 3 of Set 11 | atherton
# Processing Record 4 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 11 | neuquen
# Processing Record 6 of Set 11 | coquimbo
# Processing Record 7 of Set 11 | payo
# Processing Record 8 of Set 11 | port hawkesbury
# Processing Record 9 of Set 11 | sao filipe
# Processing Record 10 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 11 | naziya
# Processing Record 12 of Set 11 | lata
# Processing Record 13 of Set 11 | khor
# Processing Record 14 of Set 11 | isaccea
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | ongandjera
# Processing Record 17 of Set 11 | kurilsk
# Processing Record 18 of Set 11 | barao de melgaco
# Processing Record 19 of Set 11 | naantali
# Processing Record 20 of Set 11 | chukhloma
# Processing Record 21 of Set 11 | san isidro
# Processing Record 22 of Set 11 | marienburg
# Processing Record 23 of Set 11 | cervo
# Processing Record 24 of Set 11 | ilhabela
# Processing Record 25 of Set 11 | pokrovskoye
# Processing Record 26 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 11 | belmonte
# Processing Record 28 of Set 11 | vuktyl
# Processing Record 29 of Set 11 | codrington
# Processing Record 30 of Set 11 | necochea
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | nyrob
# Processing Record 33 of Set 11 | omaha
# Processing Record 34 of Set 11 | hastings
# Processing Record 35 of Set 11 | port augusta
# Processing Record 36 of Set 11 | ayagoz
# Processing Record 37 of Set 11 | moundou
# Processing Record 38 of Set 11 | tura
# Processing Record 39 of Set 11 | victoria
# Processing Record 40 of Set 11 | pyaozerskiy
# Processing Record 41 of Set 11 | dingle
# Processing Record 42 of Set 11 | tacuati
# Processing Record 43 of Set 11 | tahlequah
# Processing Record 44 of Set 11 | merrill
# Processing Record 45 of Set 11 | tshikapa
# Processing Record 46 of Set 11 | fare
# Processing Record 47 of Set 11 | baruun-urt
# Processing Record 48 of Set 11 | knysna
# Processing Record 49 of Set 11 | pangai
# Processing Record 50 of Set 11 | shonguy
# Processing Record 1 of Set 12 | lethem
# Processing Record 2 of Set 12 | andenes
# Processing Record 3 of Set 12 | dobson
# Processing Record 4 of Set 12 | hue
# Processing Record 5 of Set 12 | nadym
# Processing Record 6 of Set 12 | goya
# Processing Record 7 of Set 12 | buala
# Processing Record 8 of Set 12 | bereda
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | kupang
# Processing Record 11 of Set 12 | saint pete beach
# Processing Record 12 of Set 12 | dubbo
# Processing Record 13 of Set 12 | vallenar
# Processing Record 14 of Set 12 | miri
# Processing Record 15 of Set 12 | mbekenyera
# Processing Record 16 of Set 12 | vysokogornyy
# Processing Record 17 of Set 12 | san rafael
# Processing Record 18 of Set 12 | hovd
# Processing Record 19 of Set 12 | bonavista
# Processing Record 20 of Set 12 | carire
# Processing Record 21 of Set 12 | winnemucca
# Processing Record 22 of Set 12 | oslo
# Processing Record 23 of Set 12 | lusambo
# Processing Record 24 of Set 12 | belyy yar
# Processing Record 25 of Set 12 | kattivakkam
# Processing Record 26 of Set 12 | boone
# Processing Record 27 of Set 12 | barinas
# Processing Record 28 of Set 12 | peace river
# Processing Record 29 of Set 12 | pombas
# Processing Record 30 of Set 12 | kiama
# Processing Record 31 of Set 12 | chilakalurupet
# Processing Record 32 of Set 12 | korla
# Processing Record 33 of Set 12 | port blair
# Processing Record 34 of Set 12 | mantsala
# Processing Record 35 of Set 12 | paris
# Processing Record 36 of Set 12 | plattsburgh
# Processing Record 37 of Set 12 | yellandu
# Processing Record 38 of Set 12 | karatau
# Processing Record 39 of Set 12 | batagay
# Processing Record 40 of Set 12 | loa janan
# Processing Record 41 of Set 12 | suzun
# Processing Record 42 of Set 12 | penzance
# Processing Record 43 of Set 12 | marawi
# Processing Record 44 of Set 12 | zyryanka
# Processing Record 45 of Set 12 | porto novo
# Processing Record 46 of Set 12 | san andres
# Processing Record 47 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 12 | olean
# Processing Record 49 of Set 12 | raurkela
# City not found. Skipping...
# Processing Record 50 of Set 12 | awbari
# Processing Record 1 of Set 13 | shelburne
# Processing Record 2 of Set 13 | pyapon
# Processing Record 3 of Set 13 | puerto madero
# Processing Record 4 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 13 | vardo
# Processing Record 6 of Set 13 | paita
# Processing Record 7 of Set 13 | matai
# Processing Record 8 of Set 13 | blairmore
# Processing Record 9 of Set 13 | gorele
# Processing Record 10 of Set 13 | yerbogachen
# Processing Record 11 of Set 13 | kindu
# Processing Record 12 of Set 13 | inirida
# Processing Record 13 of Set 13 | bitkine
# Processing Record 14 of Set 13 | tabuk
# Processing Record 15 of Set 13 | mbanza-ngungu
# Processing Record 16 of Set 13 | mlimba
# Processing Record 17 of Set 13 | oyama
# Processing Record 18 of Set 13 | alexandria
# Processing Record 19 of Set 13 | sorland
# Processing Record 20 of Set 13 | coihaique
# Processing Record 21 of Set 13 | barra do garcas
# Processing Record 22 of Set 13 | upington
# Processing Record 23 of Set 13 | peniche
# Processing Record 24 of Set 13 | da nang
# Processing Record 25 of Set 13 | yarada
# Processing Record 26 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 13 | almaznyy
# Processing Record 28 of Set 13 | ughelli
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | beian
# Processing Record 31 of Set 13 | vestmannaeyjar
# Processing Record 32 of Set 13 | balaipungut
# Processing Record 33 of Set 13 | vanavara
# Processing Record 34 of Set 13 | maputo
# Processing Record 35 of Set 13 | kapit
# Processing Record 36 of Set 13 | chone
# Processing Record 37 of Set 13 | mombetsu
# Processing Record 38 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 13 | geraldton
# Processing Record 42 of Set 13 | bend
# Processing Record 43 of Set 13 | aviles
# Processing Record 44 of Set 13 | egvekinot
# Processing Record 45 of Set 13 | cravo norte
# Processing Record 46 of Set 13 | tual
# Processing Record 47 of Set 13 | abnub
# Processing Record 48 of Set 13 | barcelos
# Processing Record 49 of Set 13 | takhatpur
# Processing Record 50 of Set 13 | pochutla
# Processing Record 1 of Set 14 | noumea
# Processing Record 2 of Set 14 | tocopilla
# Processing Record 3 of Set 14 | san francisco
# Processing Record 4 of Set 14 | pangnirtung
# Processing Record 5 of Set 14 | kalmunai
# Processing Record 6 of Set 14 | ternate
# Processing Record 7 of Set 14 | lashma
# Processing Record 8 of Set 14 | komsomolskiy
# Processing Record 9 of Set 14 | poronaysk
# Processing Record 10 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | nurota
# Processing Record 12 of Set 14 | taltal
# Processing Record 13 of Set 14 | urfa
# City not found. Skipping...
# Processing Record 14 of Set 14 | salinopolis
# Processing Record 15 of Set 14 | maceio
# Processing Record 16 of Set 14 | tsumeb
# Processing Record 17 of Set 14 | matara
# Processing Record 18 of Set 14 | ballina
# Processing Record 19 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 14 | sao miguel do araguaia
# Processing Record 21 of Set 14 | kloulklubed
# Processing Record 22 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 14 | whitehorse
# Processing Record 24 of Set 14 | accra
# Processing Record 25 of Set 14 | bonito
# Processing Record 26 of Set 14 | kushuhum
# Processing Record 27 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 28 of Set 14 | evensk
# Processing Record 29 of Set 14 | honningsvag
# Processing Record 30 of Set 14 | umm lajj
# Processing Record 31 of Set 14 | hongjiang
# Processing Record 32 of Set 14 | bafoulabe
# Processing Record 33 of Set 14 | maldonado
# Processing Record 34 of Set 14 | nara
# Processing Record 35 of Set 14 | inta
# Processing Record 36 of Set 14 | marsa matruh
# Processing Record 37 of Set 14 | sheridan
# Processing Record 38 of Set 14 | mwinilunga
# Processing Record 39 of Set 14 | san quintin
# Processing Record 40 of Set 14 | dali
# Processing Record 41 of Set 14 | papasquiaro
# City not found. Skipping...
# Processing Record 42 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 14 | harlingen
# Processing Record 44 of Set 14 | sao jose da coroa grande
# Processing Record 45 of Set 14 | margate
# Processing Record 46 of Set 14 | omboue
# Processing Record 47 of Set 14 | pingliang
# Processing Record 48 of Set 14 | pretoria
# Processing Record 49 of Set 14 | eyl
# Processing Record 50 of Set 14 | channel-port aux basques
# Processing Record 1 of Set 15 | praia da vitoria
# Processing Record 2 of Set 15 | puerto leguizamo
# Processing Record 3 of Set 15 | zwedru
# Processing Record 4 of Set 15 | hohhot
# Processing Record 5 of Set 15 | wattegama
# Processing Record 6 of Set 15 | saint-pierre
# Processing Record 7 of Set 15 | tocantinopolis
# City not found. Skipping...
# Processing Record 8 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 15 | okhotsk
# Processing Record 10 of Set 15 | miandrivazo
# Processing Record 11 of Set 15 | tshane
# Processing Record 12 of Set 15 | dobreni
# Processing Record 13 of Set 15 | doha
# Processing Record 14 of Set 15 | laguna
# Processing Record 15 of Set 15 | walvis bay
# Processing Record 16 of Set 15 | tambopata
# Processing Record 17 of Set 15 | ixtapa
# Processing Record 18 of Set 15 | chapais
# Processing Record 19 of Set 15 | slave lake
# Processing Record 20 of Set 15 | tam ky
# Processing Record 21 of Set 15 | outjo
# Processing Record 22 of Set 15 | hervey bay
# Processing Record 23 of Set 15 | vagay
# Processing Record 24 of Set 15 | patulul
# Processing Record 25 of Set 15 | alegrete
# Processing Record 26 of Set 15 | dubrovnik
# Processing Record 27 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 15 | am timan
# Processing Record 29 of Set 15 | mariel
# Processing Record 30 of Set 15 | mae sai
# Processing Record 31 of Set 15 | parana
# Processing Record 32 of Set 15 | bonthe
# Processing Record 33 of Set 15 | paamiut
# Processing Record 34 of Set 15 | cockburn town
# Processing Record 35 of Set 15 | pravia
# Processing Record 36 of Set 15 | gari
# Processing Record 37 of Set 15 | rio grande
# Processing Record 38 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 15 | manjacaze
# Processing Record 40 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 15 | tyret pervaya
# Processing Record 42 of Set 15 | ugep
# Processing Record 43 of Set 15 | worland
# Processing Record 44 of Set 15 | mutoko
# Processing Record 45 of Set 15 | acapulco
# Processing Record 46 of Set 15 | omsukchan
# Processing Record 47 of Set 15 | vao
# Processing Record 48 of Set 15 | novobirilyussy
# Processing Record 49 of Set 15 | pasni
# Processing Record 50 of Set 15 | kautokeino
# Processing Record 1 of Set 16 | tongchuan
# Processing Record 2 of Set 16 | benemerito de las americas
# Processing Record 3 of Set 16 | lebedinyy
# Processing Record 4 of Set 16 | saint-ambroise
# Processing Record 5 of Set 16 | boissevain
# Processing Record 6 of Set 16 | les cayes
# Processing Record 7 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 16 | daru
# Processing Record 9 of Set 16 | morro bay
# Processing Record 10 of Set 16 | matamoros
# Processing Record 11 of Set 16 | talaya
# Processing Record 12 of Set 16 | gizo
# Processing Record 13 of Set 16 | richards bay
# Processing Record 14 of Set 16 | yantikovo
# Processing Record 15 of Set 16 | solnechnyy
# Processing Record 16 of Set 16 | port keats
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Add city data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia -54.8000  -68.3000     35.26        69          40
# 1       Kaitangata -46.2817  169.8464     45.19        92         100
# 2           Mehamn  71.0357   27.8492     55.31        94         100
# 3          Mataura -46.1927  168.8643     46.47        96         100
# 4       Butaritari   3.0707  172.7902     82.62        69          98
# 5  Bambous Virieux -20.3428   57.7575     67.21        88          40
# 6            Kalat  29.0225   66.5916     66.90        83         100
# 7         Flinders -34.5833  150.8552     65.37        80          50
# 8        Cape Town -33.9258   18.4232     58.37        69           0
# 9      Yellowknife  62.4560 -114.3525     72.12        37          40
#
#    Wind Speed Country Current Description
# 0       23.02      AR    scattered clouds
# 1       17.38      NZ       moderate rain
# 2        0.00      NO     overcast clouds
# 3       11.07      NZ          light rain
# 4       15.66      KI     overcast clouds
# 5        4.61      MU    scattered clouds
# 6        7.40      PK     overcast clouds
# 7        5.01      AU    scattered clouds
# 8        5.01      ZA           clear sky
# 9       14.97      CA    scattered clouds

# %%
# Export dataframe
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
